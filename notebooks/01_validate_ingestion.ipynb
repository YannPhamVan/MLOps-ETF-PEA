# %%
import pandas as pd
import matplotlib.pyplot as plt

etf = "EWLD_PA"
df = pd.read_parquet(f"../data/raw/{etf}.parquet")

print(df.head())
print(df.tail())
print(df.columns)

df["Close"].plot(title=f"{etf} - Closing Prices")
plt.show()
# Out:
# Price           Close       High        Low       Open  Volume
# Ticker        EWLD.PA    EWLD.PA    EWLD.PA    EWLD.PA EWLD.PA
# Date
# 2024-03-15  29.118612  29.118612  29.118612  29.118612       0
# 2024-03-18  29.418592  29.819163  29.322177  29.819163     880
# 2024-03-19  29.385792  29.714798  29.038896  29.342058    2723
# 2024-03-20  29.486183  29.680007  29.361937  29.451392    8295
# 2024-03-21  29.888741  30.191902  29.381815  29.729705   24456
# Price           Close       High        Low       Open  Volume
# Ticker        EWLD.PA    EWLD.PA    EWLD.PA    EWLD.PA EWLD.PA
# Date
# 2025-06-24  32.606998  32.702999  32.512001  32.653000   17548
# 2025-06-25  32.566002  32.756001  32.566002  32.706001   18726
# 2025-06-26  32.581001  32.624001  32.451000  32.539001    9737
# 2025-06-27  32.861000  32.861000  32.648998  32.736000   17541
# 2025-06-30  32.783001  32.917000  32.759998  32.887001   22434
# MultiIndex([( 'Close', 'EWLD.PA'),
#             (  'High', 'EWLD.PA'),
# ...
